# %% [markdown]
# # Capstone Project
# ## This Notebook is intended for the Capstone Project exercises
# <br>
# Author: Robert Jürgens

# %% [markdown]
# # The Toronto Neighbourhood Project with Geospatial Data

# %%
# %matplotlib inline

# %% [markdown]
# ## Import required Libraries

# %%
import pandas as pd
import numpy as np
import itertools

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

# %% [markdown]
# ## Retrieve Postal Codes Table from Wikipedia
# ***
# 1. Read with pandas read_html method directly from source into dataframe
#     - Restrict to table with attribute 'class wikitable sortable' as revealed by inspecting source
#     - Use row 0 for the column names
#
#
# 2. Create unique list of postal codes
#
#
# 3. Copy dataframe with rows removed for which column 'Borough' has the value 'Not assigned'
#
#
# 4. Iterate through the set of postal codes to generate a row with
#     - The Postal Code
#     - The unique Borough Name
#     - A list of Neighbourhoods for the postal code
#
#
# 5. Append that row to final data frame

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
df = pd.read_html(url,attrs={'class':'wikitable sortable'},header=0)
df_tmp = df[0][df[0]['Borough']!='Not assigned']

pc = set(df_tmp['Postcode'])

df_pc = pd.DataFrame(columns=['PostalCode','Borough','Neighbourhood','Latitude','Longitude'])

for p in pc:
    br = np.array(df_tmp[df_tmp['Postcode']==p]['Borough'].unique())[0]
    nh = np.array(df_tmp[df_tmp['Postcode']==p]['Neighbourhood'])
    if len(nh) == 1:
        if nh == 'Not assigned':
            nh = [br]
    nhs = ''
    for n in nh:
        nhs += n+','
    
    nhs = nhs[:-1]
    
    ndf = pd.DataFrame([[p,br,nhs,0.0,0.0]],columns=['PostalCode','Borough','Neighbourhood','Latitude','Longitude'])
    df_pc = df_pc.append(ndf)
    
df_pc.reset_index(drop=True,inplace=True)

# %% [markdown]
# ## Read Geospatial Data from csv as google api induces cost

# %%
gd_df = pd.read_csv('geospatial_data.csv')
gd_df.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
for i in df_pc.index:
    postal_code = df_pc.iloc[i,:]['PostalCode']

    latitude = float(gd_df.loc[gd_df['Postal Code']==postal_code]['Latitude'])
    longitude = float(gd_df.loc[gd_df['Postal Code']==postal_code]['Longitude'])
    
    df_pc.at[i,'Latitude'] = latitude
    df_pc.at[i,'Longitude'] = longitude
    

    
df_pc
# Out:
#     PostalCode           Borough  \
# 0          M9L        North York
# 1          M4C         East York
# 2          M5M        North York
# 3          M4Y  Downtown Toronto
# 4          M4N   Central Toronto
# 5          M3C        North York
# 6          M4B         East York
# 7          M2M        North York
# 8          M1V       Scarborough
# 9          M1R       Scarborough
# 10         M2H        North York
# 11         M6M              York
# 12         M2R        North York
# 13         M5P   Central Toronto
# 14         M3M        North York
# 15         M1H       Scarborough
# 16         M4L      East Toronto
# 17         M4W  Downtown Toronto
# 18         M9W         Etobicoke
# 19         M6A        North York
# 20         M4E      East Toronto
# 21         M9A         Etobicoke
# 22         M3N        North York
# 23         M3K        North York
# 24         M6P      West Toronto
# 25         M6G  Downtown Toronto
# 26         M5H  Downtown Toronto
# 27         M4P   Central Toronto
# 28         M7A      Queen's Park
# 29         M4G         East York
# ..         ...               ...
# 73         M1S       Scarborough
# 74         M1M       Scarborough
# 75         M6S      West Toronto
# 76         M4R   Central Toronto
# 77         M5T  Downtown Toronto
# 78         M5X  Downtown Toronto
# 79         M9P         Etobicoke
# 80         M6E              York
# 81         M5R   Central Toronto
# 82         M9C         Etobicoke
# 83         M6C              York
# 84         M3J        North York
# 85         M9V         Etobicoke
# 86         M2L        North York
# 87         M1B       Scarborough
# 88         M1N       Scarborough
# 89         M4X  Downtown Toronto
# 90         M5L  Downtown Toronto
# 91         M6L        North York
# 92         M5V  Downtown Toronto
# 93         M5C  Downtown Toronto
# 94         M2K        North York
# 95         M9B         Etobicoke
# 96         M2P        North York
# 97         M3H        North York
# 98         M8Z         Etobicoke
# 99         M4V   Central Toronto
# 100        M5J  Downtown Toronto
# 101        M4S   Central Toronto
# 102        M9R         Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                        Humber Summit  43.756303 -79.565963
# 1                                     Woodbine Heights  43.695344 -79.318389
# 2                     Bedford Park,Lawrence Manor East  43.733283 -79.419750
# 3                                 Church and Wellesley  43.665860 -79.383160
# 4                                        Lawrence Park  43.728020 -79.388790
# 5                      Flemingdon Park,Don Mills South  43.725900 -79.340923
# 6                       Woodbine Gardens,Parkview Hill  43.706397 -79.309937
# 7                               Newtonbrook,Willowdale  43.789053 -79.408493
# 8    Agincourt North,L'Amoreaux East,Milliken,Steel...  43.815252 -79.284577
# 9                                     Maryvale,Wexford  43.750072 -79.295849
# 10                                   Hillcrest Village  43.803762 -79.363452
# 11         Del Ray,Keelesdale,Mount Dennis,Silverthorn  43.691116 -79.476013
# 12                                     Willowdale West  43.782736 -79.442259
# 13                  Forest Hill North,Forest Hill West  43.696948 -79.411307
# 14                                   Downsview Central  43.728496 -79.495697
# 15                                           Cedarbrae  43.773136 -79.239476
# 16                       The Beaches West,India Bazaar  43.668999 -79.315572
# 17                                            Rosedale  43.679563 -79.377529
# 18                                           Northwest  43.706748 -79.594054
# 19                     Lawrence Heights,Lawrence Manor  43.718518 -79.464763
# 20                                         The Beaches  43.676357 -79.293031
# 21                                    Islington Avenue  43.667856 -79.532242
# 22                                 Downsview Northwest  43.761631 -79.520999
# 23                          CFB Toronto,Downsview East  43.737473 -79.464763
# 24                        High Park,The Junction South  43.661608 -79.464763
# 25                                            Christie  43.669542 -79.422564
# 26                              Adelaide,King,Richmond  43.650571 -79.384568
# 27                                    Davisville North  43.712751 -79.390197
# 28                                        Queen's Park  43.662301 -79.389494
# 29                                             Leaside  43.709060 -79.363452
# ..                                                 ...        ...        ...
# 73                                           Agincourt  43.794200 -79.262029
# 74       Cliffcrest,Cliffside,Scarborough Village West  43.716316 -79.239476
# 75                                   Runnymede,Swansea  43.651571 -79.484450
# 76                                  North Toronto West  43.715383 -79.405678
# 77             Chinatown,Grange Park,Kensington Market  43.653206 -79.400049
# 78               First Canadian Place,Underground city  43.648429 -79.382280
# 79                                           Westmount  43.696319 -79.532242
# 80                                 Caledonia-Fairbanks  43.689026 -79.453512
# 81                   The Annex,North Midtown,Yorkville  43.672710 -79.405678
# 82   Bloordale Gardens,Eringate,Markland Wood,Old B...  43.643515 -79.577201
# 83                                  Humewood-Cedarvale  43.693781 -79.428191
# 84                      Northwood Park,York University  43.767980 -79.487262
# 85   Albion Gardens,Beaumond Heights,Humbergate,Jam...  43.739416 -79.588437
# 86                             Silver Hills,York Mills  43.757490 -79.374714
# 87                                       Rouge,Malvern  43.806686 -79.194353
# 88                          Birch Cliff,Cliffside West  43.692657 -79.264848
# 89                          Cabbagetown,St. James Town  43.667967 -79.367675
# 90                       Commerce Court,Victoria Hotel  43.648198 -79.379817
# 91                    Downsview,North Park,Upwood Park  43.713756 -79.490074
# 92   CN Tower,Bathurst Quay,Island airport,Harbourf...  43.628947 -79.394420
# 93                                      St. James Town  43.651494 -79.375418
# 94                                     Bayview Village  43.786947 -79.385975
# 95   Cloverdale,Islington,Martin Grove,Princess Gar...  43.650943 -79.554724
# 96                                     York Mills West  43.752758 -79.400049
# 97       Bathurst Manor,Downsview North,Wilson Heights  43.754328 -79.442259
# 98   Kingsway Park South West,Mimico NW,The Queensw...  43.628841 -79.520999
# 99   Deer Park,Forest Hill SE,Rathnelly,South Hill,...  43.686412 -79.400049
# 100    Harbourfront East,Toronto Islands,Union Station  43.640816 -79.381752
# 101                                         Davisville  43.704324 -79.388790
# 102  Kingsview Village,Martin Grove Gardens,Richvie...  43.688905 -79.554724
#
# [103 rows x 5 columns]
